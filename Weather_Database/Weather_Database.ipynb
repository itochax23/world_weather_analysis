# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({
                          "City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | swan river
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 1 | marienburg
# Processing Record 10 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | nouakchott
# Processing Record 18 of Set 1 | lashio
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | tessalit
# Processing Record 25 of Set 1 | vestmannaeyjar
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | parbhani
# Processing Record 30 of Set 1 | paita
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | tara
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | harper
# Processing Record 45 of Set 1 | north bend
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | qianan
# Processing Record 48 of Set 1 | de-kastri
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | redmond
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | mahajanga
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | kamenka
# Processing Record 10 of Set 2 | ca mau
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | ostrovnoy
# Processing Record 13 of Set 2 | fangshan
# Processing Record 14 of Set 2 | puerto escondido
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | richard toll
# City not found. Skipping...
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | talnakh
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | labuhan
# Processing Record 23 of Set 2 | tazovskiy
# Processing Record 24 of Set 2 | galesong
# Processing Record 25 of Set 2 | yumen
# Processing Record 26 of Set 2 | bilma
# Processing Record 27 of Set 2 | lamu
# Processing Record 28 of Set 2 | tiarei
# Processing Record 29 of Set 2 | pulivendla
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | north platte
# Processing Record 34 of Set 2 | labrea
# Processing Record 35 of Set 2 | san policarpo
# Processing Record 36 of Set 2 | la rioja
# Processing Record 37 of Set 2 | thinadhoo
# Processing Record 38 of Set 2 | manturovo
# Processing Record 39 of Set 2 | baragua
# Processing Record 40 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | provideniya
# Processing Record 43 of Set 2 | krasnoselkup
# Processing Record 44 of Set 2 | byron bay
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | ende
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | tochtepec
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | wahiawa
# Processing Record 3 of Set 3 | lokosovo
# Processing Record 4 of Set 3 | muros
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | laela
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | dingle
# Processing Record 9 of Set 3 | bilibino
# Processing Record 10 of Set 3 | husavik
# Processing Record 11 of Set 3 | coihaique
# Processing Record 12 of Set 3 | rexburg
# Processing Record 13 of Set 3 | vuktyl
# Processing Record 14 of Set 3 | coahuayana
# Processing Record 15 of Set 3 | kita
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | tarko-sale
# Processing Record 18 of Set 3 | sao gabriel da cachoeira
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | marsh harbour
# Processing Record 21 of Set 3 | vradiyivka
# Processing Record 22 of Set 3 | poum
# Processing Record 23 of Set 3 | roald
# Processing Record 24 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | aykhal
# Processing Record 27 of Set 3 | russellville
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | coquimbo
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | xingyi
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 3 | kiunga
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | virginia beach
# Processing Record 44 of Set 3 | kudahuvadhoo
# Processing Record 45 of Set 3 | whitehorse
# Processing Record 46 of Set 3 | hearst
# Processing Record 47 of Set 3 | bollnas
# Processing Record 48 of Set 3 | domoni
# Processing Record 49 of Set 3 | evensk
# Processing Record 50 of Set 3 | kurumkan
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | camacha
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | madang
# Processing Record 5 of Set 4 | rocha
# Processing Record 6 of Set 4 | stephenville
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | maniitsoq
# Processing Record 9 of Set 4 | saint anthony
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | ossora
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | hovd
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | presidente epitacio
# Processing Record 16 of Set 4 | tres lagoas
# Processing Record 17 of Set 4 | seoul
# Processing Record 18 of Set 4 | sorland
# Processing Record 19 of Set 4 | jose bonifacio
# Processing Record 20 of Set 4 | tienchung
# City not found. Skipping...
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | samarai
# Processing Record 23 of Set 4 | ust-kuyga
# Processing Record 24 of Set 4 | inirida
# Processing Record 25 of Set 4 | shelburne
# Processing Record 26 of Set 4 | vilhena
# Processing Record 27 of Set 4 | certesti
# Processing Record 28 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 4 | swinoujscie
# Processing Record 30 of Set 4 | sarab
# Processing Record 31 of Set 4 | taoudenni
# Processing Record 32 of Set 4 | gizo
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | victoria
# Processing Record 35 of Set 4 | terra santa
# Processing Record 36 of Set 4 | erzin
# Processing Record 37 of Set 4 | marigot
# Processing Record 38 of Set 4 | mitsamiouli
# Processing Record 39 of Set 4 | buala
# Processing Record 40 of Set 4 | ewa beach
# Processing Record 41 of Set 4 | rock springs
# Processing Record 42 of Set 4 | puerto ayora
# Processing Record 43 of Set 4 | batemans bay
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | heihe
# Processing Record 46 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 | cabo rojo
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | qui nhon
# Processing Record 50 of Set 4 | wajima
# Processing Record 1 of Set 5 | bobrovka
# Processing Record 2 of Set 5 | leningradskiy
# Processing Record 3 of Set 5 | kytlym
# City not found. Skipping...
# Processing Record 4 of Set 5 | shimoda
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 5 | waipawa
# Processing Record 8 of Set 5 | aonla
# Processing Record 9 of Set 5 | mwinilunga
# Processing Record 10 of Set 5 | saint-claude
# Processing Record 11 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 5 | uyuni
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | labuan
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | inhambane
# Processing Record 17 of Set 5 | bowen
# Processing Record 18 of Set 5 | naze
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | havre-saint-pierre
# Processing Record 22 of Set 5 | pafos
# Processing Record 23 of Set 5 | colares
# Processing Record 24 of Set 5 | karratha
# Processing Record 25 of Set 5 | baltasi
# Processing Record 26 of Set 5 | la ronge
# Processing Record 27 of Set 5 | paraguacu
# Processing Record 28 of Set 5 | santa isabel do rio negro
# Processing Record 29 of Set 5 | wilmington
# Processing Record 30 of Set 5 | veracruz
# Processing Record 31 of Set 5 | sitka
# Processing Record 32 of Set 5 | natal
# Processing Record 33 of Set 5 | ketchikan
# Processing Record 34 of Set 5 | umm kaddadah
# Processing Record 35 of Set 5 | helong
# Processing Record 36 of Set 5 | ocos
# Processing Record 37 of Set 5 | roros
# Processing Record 38 of Set 5 | lluta
# Processing Record 39 of Set 5 | te anau
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | turukhansk
# Processing Record 42 of Set 5 | varhaug
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | kutum
# Processing Record 45 of Set 5 | lakatoro
# Processing Record 46 of Set 5 | iguape
# Processing Record 47 of Set 5 | san cristobal
# Processing Record 48 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | saint-augustin
# Processing Record 50 of Set 5 | mae hong son
# Processing Record 1 of Set 6 | borzya
# Processing Record 2 of Set 6 | namtsy
# Processing Record 3 of Set 6 | ambon
# Processing Record 4 of Set 6 | thompson
# Processing Record 5 of Set 6 | maneadero
# Processing Record 6 of Set 6 | oksbol
# Processing Record 7 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 6 | caranavi
# Processing Record 9 of Set 6 | ochamchira
# Processing Record 10 of Set 6 | mattawa
# Processing Record 11 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 6 | diamantino
# Processing Record 16 of Set 6 | faanui
# Processing Record 17 of Set 6 | nobres
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | castro
# Processing Record 20 of Set 6 | tairua
# Processing Record 21 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | bambanglipuro
# Processing Record 24 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | faya
# Processing Record 27 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 6 | sodertalje
# City not found. Skipping...
# Processing Record 29 of Set 6 | carutapera
# Processing Record 30 of Set 6 | vanimo
# Processing Record 31 of Set 6 | wanning
# Processing Record 32 of Set 6 | paarl
# Processing Record 33 of Set 6 | moron
# Processing Record 34 of Set 6 | plonsk
# Processing Record 35 of Set 6 | yangliuqing
# Processing Record 36 of Set 6 | ugento
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | arroio grande
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | umtata
# Processing Record 41 of Set 6 | vesyegonsk
# Processing Record 42 of Set 6 | esperance
# Processing Record 43 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 6 | linxi
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | hanyang
# Processing Record 47 of Set 6 | jacareacanga
# Processing Record 48 of Set 6 | burnie
# Processing Record 49 of Set 6 | matara
# Processing Record 50 of Set 6 | college
# Processing Record 1 of Set 7 | merauke
# Processing Record 2 of Set 7 | rakhya
# City not found. Skipping...
# Processing Record 3 of Set 7 | margate
# Processing Record 4 of Set 7 | slave lake
# Processing Record 5 of Set 7 | kurchum
# Processing Record 6 of Set 7 | omsukchan
# Processing Record 7 of Set 7 | zhaoqing
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | kolarovo
# Processing Record 10 of Set 7 | lac du bonnet
# Processing Record 11 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 12 of Set 7 | willowmore
# Processing Record 13 of Set 7 | garden city
# Processing Record 14 of Set 7 | banjar
# Processing Record 15 of Set 7 | miraflores
# Processing Record 16 of Set 7 | yagodnoye
# Processing Record 17 of Set 7 | sabang
# Processing Record 18 of Set 7 | dumaguil
# Processing Record 19 of Set 7 | jiangyou
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | elliot lake
# Processing Record 22 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 7 | nouadhibou
# Processing Record 24 of Set 7 | boguchany
# Processing Record 25 of Set 7 | okhotsk
# Processing Record 26 of Set 7 | itacare
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | prince rupert
# Processing Record 29 of Set 7 | akdepe
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | lavrentiya
# Processing Record 32 of Set 7 | bonthe
# Processing Record 33 of Set 7 | east london
# Processing Record 34 of Set 7 | porto empedocle
# Processing Record 35 of Set 7 | antequera
# Processing Record 36 of Set 7 | morondava
# Processing Record 37 of Set 7 | marathon
# Processing Record 38 of Set 7 | saint-georges
# Processing Record 39 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 7 | berlevag
# Processing Record 41 of Set 7 | suez
# Processing Record 42 of Set 7 | matagami
# Processing Record 43 of Set 7 | port lincoln
# Processing Record 44 of Set 7 | iquitos
# Processing Record 45 of Set 7 | norman wells
# Processing Record 46 of Set 7 | rudnichnyy
# Processing Record 47 of Set 7 | kaoma
# Processing Record 48 of Set 7 | dorokhovo
# Processing Record 49 of Set 7 | abha
# Processing Record 50 of Set 7 | olafsvik
# Processing Record 1 of Set 8 | grand-bourg
# Processing Record 2 of Set 8 | coos bay
# Processing Record 3 of Set 8 | san diego de la union
# Processing Record 4 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 8 | russell
# Processing Record 6 of Set 8 | shebalino
# Processing Record 7 of Set 8 | kralendijk
# Processing Record 8 of Set 8 | kenora
# Processing Record 9 of Set 8 | fowa
# Processing Record 10 of Set 8 | liverpool
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | filadelfia
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | constitucion
# Processing Record 15 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 8 | kazachinskoye
# Processing Record 18 of Set 8 | flinders
# Processing Record 19 of Set 8 | tavda
# Processing Record 20 of Set 8 | nanning
# Processing Record 21 of Set 8 | anchorage
# Processing Record 22 of Set 8 | yakshur-bodya
# City not found. Skipping...
# Processing Record 23 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 24 of Set 8 | kalmunai
# Processing Record 25 of Set 8 | nanakuli
# Processing Record 26 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 8 | lagoa
# Processing Record 28 of Set 8 | sao francisco do sul
# Processing Record 29 of Set 8 | zhigansk
# Processing Record 30 of Set 8 | louis trichardt
# Processing Record 31 of Set 8 | shenjiamen
# Processing Record 32 of Set 8 | half moon bay
# Processing Record 33 of Set 8 | jumla
# Processing Record 34 of Set 8 | san martin
# Processing Record 35 of Set 8 | los llanos de aridane
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | plettenberg bay
# Processing Record 38 of Set 8 | ahuimanu
# Processing Record 39 of Set 8 | zadar
# Processing Record 40 of Set 8 | kungurtug
# Processing Record 41 of Set 8 | doxey
# Processing Record 42 of Set 8 | longyearbyen
# Processing Record 43 of Set 8 | constantine
# Processing Record 44 of Set 8 | samana
# Processing Record 45 of Set 8 | yulara
# Processing Record 46 of Set 8 | hokitika
# Processing Record 47 of Set 8 | sarangani
# Processing Record 48 of Set 8 | homer
# Processing Record 49 of Set 8 | san andres
# Processing Record 50 of Set 8 | gravdal
# Processing Record 1 of Set 9 | glendive
# Processing Record 2 of Set 9 | lasa
# Processing Record 3 of Set 9 | baie-comeau
# Processing Record 4 of Set 9 | harnosand
# Processing Record 5 of Set 9 | neuquen
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | luganville
# Processing Record 8 of Set 9 | sobolevo
# Processing Record 9 of Set 9 | vrangel
# Processing Record 10 of Set 9 | henties bay
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | tres arroyos
# Processing Record 13 of Set 9 | curiti
# Processing Record 14 of Set 9 | popondetta
# Processing Record 15 of Set 9 | katsuura
# Processing Record 16 of Set 9 | akyab
# Processing Record 17 of Set 9 | demba
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | gigmoto
# Processing Record 20 of Set 9 | meulaboh
# Processing Record 21 of Set 9 | saint-pierre
# Processing Record 22 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 9 | seddon
# Processing Record 24 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 9 | imeni zhelyabova
# Processing Record 26 of Set 9 | kazanskoye
# Processing Record 27 of Set 9 | charters towers
# Processing Record 28 of Set 9 | mahebourg
# Processing Record 29 of Set 9 | bulungu
# Processing Record 30 of Set 9 | cacule
# Processing Record 31 of Set 9 | barentu
# Processing Record 32 of Set 9 | amparai
# City not found. Skipping...
# Processing Record 33 of Set 9 | arinos
# Processing Record 34 of Set 9 | almaznyy
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | sorong
# Processing Record 37 of Set 9 | vao
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | teguise
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | vaxjo
# Processing Record 42 of Set 9 | tsabong
# Processing Record 43 of Set 9 | bathsheba
# Processing Record 44 of Set 9 | enid
# Processing Record 45 of Set 9 | minot
# Processing Record 46 of Set 9 | kimbe
# Processing Record 47 of Set 9 | mulege
# Processing Record 48 of Set 9 | katherine
# Processing Record 49 of Set 9 | nipawin
# Processing Record 50 of Set 9 | egvekinot
# Processing Record 1 of Set 10 | ahipara
# Processing Record 2 of Set 10 | encruzilhada
# Processing Record 3 of Set 10 | mackenzie
# Processing Record 4 of Set 10 | giyani
# Processing Record 5 of Set 10 | alice springs
# Processing Record 6 of Set 10 | baykit
# Processing Record 7 of Set 10 | garowe
# Processing Record 8 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 10 | sinnamary
# Processing Record 10 of Set 10 | hurricane
# Processing Record 11 of Set 10 | diego de almagro
# Processing Record 12 of Set 10 | saravan
# Processing Record 13 of Set 10 | yanam
# Processing Record 14 of Set 10 | balkhash
# Processing Record 15 of Set 10 | batagay
# Processing Record 16 of Set 10 | uk
# City not found. Skipping...
# Processing Record 17 of Set 10 | sabaneta
# Processing Record 18 of Set 10 | nyurba
# Processing Record 19 of Set 10 | stawell
# Processing Record 20 of Set 10 | fairbanks
# Processing Record 21 of Set 10 | teya
# Processing Record 22 of Set 10 | leshukonskoye
# Processing Record 23 of Set 10 | verkhoyansk
# Processing Record 24 of Set 10 | emerald
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 10 | namibe
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | san jeronimo
# Processing Record 30 of Set 10 | high rock
# Processing Record 31 of Set 10 | caraballeda
# Processing Record 32 of Set 10 | iranshahr
# Processing Record 33 of Set 10 | colesberg
# Processing Record 34 of Set 10 | praya
# Processing Record 35 of Set 10 | bubaque
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | nemuro
# Processing Record 38 of Set 10 | svetlyy
# Processing Record 39 of Set 10 | fortuna
# Processing Record 40 of Set 10 | chicama
# Processing Record 41 of Set 10 | baikunthpur
# Processing Record 42 of Set 10 | berbera
# Processing Record 43 of Set 10 | flin flon
# Processing Record 44 of Set 10 | ithaca
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | vila franca do campo
# Processing Record 47 of Set 10 | jadu
# Processing Record 48 of Set 10 | bada
# Processing Record 49 of Set 10 | belmonte
# Processing Record 50 of Set 10 | santiago de cao
# Processing Record 1 of Set 11 | redcliffe
# Processing Record 2 of Set 11 | port blair
# Processing Record 3 of Set 11 | bairiki
# Processing Record 4 of Set 11 | santa marta
# Processing Record 5 of Set 11 | obihiro
# Processing Record 6 of Set 11 | richards bay
# Processing Record 7 of Set 11 | leh
# Processing Record 8 of Set 11 | barcelos
# Processing Record 9 of Set 11 | cidreira
# Processing Record 10 of Set 11 | vung tau
# Processing Record 11 of Set 11 | severo-yeniseyskiy
# Processing Record 12 of Set 11 | santiago
# Processing Record 13 of Set 11 | andros
# Processing Record 14 of Set 11 | tezu
# Processing Record 15 of Set 11 | kirovohrad
# Processing Record 16 of Set 11 | ken caryl
# Processing Record 17 of Set 11 | aksu
# Processing Record 18 of Set 11 | sechura
# Processing Record 19 of Set 11 | kukushtan
# Processing Record 20 of Set 11 | kovernino
# Processing Record 21 of Set 11 | chumikan
# Processing Record 22 of Set 11 | sept-iles
# Processing Record 23 of Set 11 | taksimo
# Processing Record 24 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 11 | nome
# Processing Record 26 of Set 11 | sehithwa
# Processing Record 27 of Set 11 | shingu
# Processing Record 28 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 11 | calvinia
# Processing Record 30 of Set 11 | miri
# Processing Record 31 of Set 11 | mount gambier
# Processing Record 32 of Set 11 | pozo colorado
# Processing Record 33 of Set 11 | tura
# Processing Record 34 of Set 11 | beyneu
# Processing Record 35 of Set 11 | sao filipe
# Processing Record 36 of Set 11 | galveston
# Processing Record 37 of Set 11 | viransehir
# Processing Record 38 of Set 11 | mnogovershinnyy
# Processing Record 39 of Set 11 | roma
# Processing Record 40 of Set 11 | praxedis guerrero
# Processing Record 41 of Set 11 | chaman
# Processing Record 42 of Set 11 | choya
# Processing Record 43 of Set 11 | zeya
# Processing Record 44 of Set 11 | oni
# Processing Record 45 of Set 11 | monte cristi
# City not found. Skipping...
# Processing Record 46 of Set 11 | ryotsu
# Processing Record 47 of Set 11 | ati
# Processing Record 48 of Set 11 | dabakala
# Processing Record 49 of Set 11 | phillipsburg
# Processing Record 50 of Set 11 | venezuela
# Processing Record 1 of Set 12 | uyemskiy
# Processing Record 2 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 3 of Set 12 | northam
# Processing Record 4 of Set 12 | quang ngai
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 7 of Set 12 | nicolas bravo
# Processing Record 8 of Set 12 | tuy hoa
# Processing Record 9 of Set 12 | coolum beach
# Processing Record 10 of Set 12 | senneterre
# Processing Record 11 of Set 12 | presidencia roque saenz pena
# Processing Record 12 of Set 12 | koslan
# Processing Record 13 of Set 12 | nabire
# Processing Record 14 of Set 12 | upata
# Processing Record 15 of Set 12 | vostok
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | kahului
# Processing Record 18 of Set 12 | yaan
# Processing Record 19 of Set 12 | avera
# Processing Record 20 of Set 12 | piove di sacco
# Processing Record 21 of Set 12 | emba
# Processing Record 22 of Set 12 | del rio
# Processing Record 23 of Set 12 | balaipungut
# Processing Record 24 of Set 12 | liwale
# Processing Record 25 of Set 12 | korla
# Processing Record 26 of Set 12 | puerto del rosario
# Processing Record 27 of Set 12 | saltillo
# Processing Record 28 of Set 12 | deputatskiy
# Processing Record 29 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 12 | onda
# Processing Record 31 of Set 12 | neftcala
# Processing Record 32 of Set 12 | normandin
# Processing Record 33 of Set 12 | along
# Processing Record 34 of Set 12 | mirnyy
# Processing Record 35 of Set 12 | dosso
# Processing Record 36 of Set 12 | morehead
# Processing Record 37 of Set 12 | altoona
# Processing Record 38 of Set 12 | lakki marwat
# Processing Record 39 of Set 12 | ardakan
# Processing Record 40 of Set 12 | mendoza
# Processing Record 41 of Set 12 | myaundzha
# Processing Record 42 of Set 12 | asadabad
# Processing Record 43 of Set 12 | kupino
# Processing Record 44 of Set 12 | wairoa
# Processing Record 45 of Set 12 | santa ines
# Processing Record 46 of Set 12 | kuyanovo
# Processing Record 47 of Set 12 | birnin kebbi
# Processing Record 48 of Set 12 | epernay
# Processing Record 49 of Set 12 | birao
# Processing Record 50 of Set 12 | burica
# City not found. Skipping...
# Processing Record 1 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 13 | arica
# Processing Record 3 of Set 13 | orsha
# Processing Record 4 of Set 13 | mbaiki
# Processing Record 5 of Set 13 | corner brook
# Processing Record 6 of Set 13 | conde
# Processing Record 7 of Set 13 | bachaquero
# Processing Record 8 of Set 13 | valleyview
# Processing Record 9 of Set 13 | maues
# Processing Record 10 of Set 13 | oranjemund
# Processing Record 11 of Set 13 | yeppoon
# Processing Record 12 of Set 13 | kibondo
# Processing Record 13 of Set 13 | hualmay
# Processing Record 14 of Set 13 | jackson
# Processing Record 15 of Set 13 | meyungs
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 559

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Jamestown      US  42.0970  -79.2353     76.17        59           1
# 1          Ushuaia      AR -54.8000  -68.3000     38.82        70          40
# 2       Swan River      CA  52.1058 -101.2676     83.71        29          23
# 3           Bethel      US  41.3712  -73.4140     88.02        74          75
# 4       Nanortalik      GL  60.1432  -45.2371     50.25        90         100
# 5  Bambous Virieux      MU -20.3428   57.7575     72.21        76          19
# 6           Hobart      AU -42.8794  147.3294     55.26        61          75
# 7       Marienburg      PL  54.0359   19.0266     79.84        38          71
# 8          Rikitea      PF -23.1203 -134.9692     74.05        82          97
# 9         Khatanga      RU  71.9667  102.5000     52.30        66         100
#
#    Wind Speed Current Description
# 0        1.99           clear sky
# 1        0.00    scattered clouds
# 2       19.42          few clouds
# 3        4.00       broken clouds
# 4        8.28     overcast clouds
# 5       15.97          few clouds
# 6        4.00       broken clouds
# 7        8.84       broken clouds
# 8       17.02          light rain
# 9        4.03     overcast clouds

# %%
# Create a new folder called "weather_data." Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
